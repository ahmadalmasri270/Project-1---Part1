# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadalmasri270/sales-predictions/blob/main/styling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount data

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# load data set

# %%
df=pd.read_csv('/content/drive/MyDrive/Coding Dojo/athleteEventsNoPersonal.csv')
df.tail()
# Out:
#            ID   Age  Height    Team  NOC        Games  Year  Season  \
# 40611  135567  28.0   183.0  Russia  RUS  2004 Summer  2004  Summer
# 40612  135570  27.0   176.0  Poland  POL  2014 Winter  2014  Winter
# 40613  135570  27.0   176.0  Poland  POL  2014 Winter  2014  Winter
# 40614  135571  30.0   185.0  Poland  POL  1998 Winter  1998  Winter
# 40615  135571  34.0   185.0  Poland  POL  2002 Winter  2002  Winter
#
#                  City        Sport                                     Event  \
# 40611          Athina       Rowing    Rowing Men's Lightweight Coxless Fours
# 40612           Sochi  Ski Jumping  Ski Jumping Men's Large Hill, Individual
# 40613           Sochi  Ski Jumping        Ski Jumping Men's Large Hill, Team
# 40614          Nagano    Bobsleigh                      Bobsleigh Men's Four
# 40615  Salt Lake City    Bobsleigh                      Bobsleigh Men's Four
#
#       Medal
# 40611   NaN
# 40612   NaN
# 40613   NaN
# 40614   NaN
# 40615   NaN

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ## get number of olympians per year

# %%
from pandas.core.groupby.groupby import GroupBy
num_uniq_year= df.groupby(['Year'])['ID'].nunique()
print(num_uniq_year.max())
# this is a pandas Series
num_uniq_year
# Out:
# 1693
# Year
# 1896      26
# 1900     178
# 1904      91
# 1906     125
# 1908     312
# 1912     347
# 1920     392
# 1924     537
# 1928     550
# 1932     336
# 1936     771
# 1948     756
# 1952     877
# 1956     595
# 1960     901
# 1964     885
# 1968     973
# 1972    1210
# 1976    1086
# 1980     968
# 1984    1190
# 1988    1527
# 1992    1693
# 1994     290
# 1996    1512
# 1998     343
# 2000    1611
# 2002     369
# 2004    1598
# 2006     376
# 2008    1672
# 2010     374
# 2012    1597
# 2014     429
# 2016    1692
# Name: ID, dtype: int64

# %%
# Can convert to NumPy array or list
num_uniq_yearin = np.array(num_uniq_year.index)
#numOlympian = np.array(num_uniq_year.values)
num_uniq_yearin
# Out:
# array([1896, 1900, 1904, 1906, 1908, 1912, 1920, 1924, 1928, 1932, 1936,
#        1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988,
#        1992, 1994, 1996, 1998, 2000, 2002, 2004, 2006, 2008, 2010, 2012,
#        2014, 2016])

# %%
numOlympian = np.array(num_uniq_year.values)
numOlympian
# Out:
# array([  26,  178,   91,  125,  312,  347,  392,  537,  550,  336,  771,
#         756,  877,  595,  901,  885,  973, 1210, 1086,  968, 1190, 1527,
#        1693,  290, 1512,  343, 1611,  369, 1598,  376, 1672,  374, 1597,
#         429, 1692])

# %%
# Make the style by default seaborn
plt.style.use('seaborn-pastel')

# %%
# Plot graph showing how it would look with defaults
plt.plot(num_uniq_yearin, numOlympian, c= 'B')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/events.py:88: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   func(*args, **kwargs)

# %%
#MATLAB-style
# Set xlim and ylim
plt.plot(num_uniq_yearin, numOlympian, c = 'magenta', marker = '*', markersize = 10)
plt.xlim(left=1892,right=2020)
plt.ylim(bottom=0,top=1800)
plt.xlabel('Year')
plt.ylabel('Number of Olympians')
plt.title('Number of Olympians Over the Years')
# Out:
# Text(0.5, 1.0, 'Number of Olympians Over the Years')

# %%
# Change fontsize
fig, axes = plt.subplots(nrows = 1, ncols = 1)
axes.plot(num_uniq_yearin, numOlympian, c= 'k');
axes.set_xlim(left=1892,right=2020)
axes.set_ylim(bottom=0,top=1800)
axes.set_xlabel('Year', fontsize = 16)
axes.set_ylabel('Number of Olympians', fontsize = 16)
axes.set_title('Number of Olympians Over the Years', fontsize = 16)
#axes.legend(loc=(1.02,0))
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
# change color of grid lines, transparency, and linestyle
plt.plot(num_uniq_yearin, numOlympian, c= 'k')
plt.grid(c = 'g', 
         alpha = .9,
         linestyle = '-')
plt.scatter(num_uniq_yearin, numOlympian, c= 'k', label = 'Actual')

# %%
plt.plot(num_uniq_yearin, numOlympian, c = 'r', label = 'year')
# actual
plt.scatter(num_uniq_yearin, numOlympian, c= 'k', label = 'number')
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1);
# predictions (best fit line)
axes.plot(num_uniq_yearin, numOlympian, c = 'r', label = 'Prediction')
# actual
axes.scatter(num_uniq_yearin, numOlympian, c= 'k', label = 'Actual')
axes.legend(loc=(1.02,0))
